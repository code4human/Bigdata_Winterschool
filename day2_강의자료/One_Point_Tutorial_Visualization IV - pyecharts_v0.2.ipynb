# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # &#128013; [One Point Tutorial] Visualization IV - `pyecharts`
# <p style='text-align: right;'> Python을 활용한 데이터 시각화 </p>
# <p style='text-align: right;'> December, 2019</p>
#
# ---
#
# ## 4. *<font color="green">pyecharts</font>*를 배워 보자 !
#
# - **pyecharts이란?**
#  1. Baidu에서 데이터 시각화를 위해 만든 Echarts.js의 파이썬 버전
#  2. 정말 다양한 그래프들이 내장되어 있어 레포트를 작성할 때 좋음
#  3. pyecharts는 별도의 웹 페이지를 생성 할 수도있는 플라스크, 장고에 통합 사용할 수 있음
#
#
# ### 학습 목표
# `pyecharts`의 핵심적인 시각화 기법을 이해하고 활용함
#
# ### 목차
#  1. Bar Plot
#  2. Line Plot
#  3. Pie Plot
#  4. Box Plot
#  5. Funnel plot
#  6. Gauge Graph

# %% [markdown]
# ### Import module (모듈 설치 후 불러오기)

# %%
#!pip install -U setuptools
#!pip install -U wheel
#xcode-select --install

# %%
import numpy as np
import pandas as pd

# !pip install pyecharts==0.5.8
#!pip install pyecharts-jupyter-installer==0.0.3
import pyecharts

import os
# Out:
# Requirement already satisfied: pyecharts==0.5.8 in c:\users\kim taeeun\anaconda3\lib\site-packages (0.5.8)
# Requirement already satisfied: future in c:\users\kim taeeun\anaconda3\lib\site-packages (from pyecharts==0.5.8) (0.17.1)
# Requirement already satisfied: jupyter-echarts-pypkg==0.1.2 in c:\users\kim taeeun\anaconda3\lib\site-packages (from pyecharts==0.5.8) (0.1.2)
# Requirement already satisfied: pillow in c:\users\kim taeeun\anaconda3\lib\site-packages (from pyecharts==0.5.8) (6.2.0)
# Requirement already satisfied: lml==0.0.2 in c:\users\kim taeeun\anaconda3\lib\site-packages (from pyecharts==0.5.8) (0.0.2)
# Requirement already satisfied: jinja2 in c:\users\kim taeeun\anaconda3\lib\site-packages (from pyecharts==0.5.8) (2.10.3)
# Requirement already satisfied: pyecharts-javascripthon==0.0.6 in c:\users\kim taeeun\anaconda3\lib\site-packages (from pyecharts==0.5.8) (0.0.6)
# Requirement already satisfied: pyecharts-jupyter-installer==0.0.3 in c:\users\kim taeeun\anaconda3\lib\site-packages (from jupyter-echarts-pypkg==0.1.2->pyecharts==0.5.8) (0.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kim taeeun\anaconda3\lib\site-packages (from jinja2->pyecharts==0.5.8) (1.1.1)
# Requirement already satisfied: javascripthon>=0.10; python_version > "3.4" in c:\users\kim taeeun\anaconda3\lib\site-packages (from pyecharts-javascripthon==0.0.6->pyecharts==0.5.8) (0.10)
# Requirement already satisfied: dukpy in c:\users\kim taeeun\anaconda3\lib\site-packages (from javascripthon>=0.10; python_version > "3.4"->pyecharts-javascripthon==0.0.6->pyecharts==0.5.8) (0.2.2)
# Requirement already satisfied: macropy3==1.1.0b2 in c:\users\kim taeeun\anaconda3\lib\site-packages (from javascripthon>=0.10; python_version > "3.4"->pyecharts-javascripthon==0.0.6->pyecharts==0.5.8) (1.1.0b2)
# Requirement already satisfied: setuptools in c:\users\kim taeeun\anaconda3\lib\site-packages (from javascripthon>=0.10; python_version > "3.4"->pyecharts-javascripthon==0.0.6->pyecharts==0.5.8) (42.0.2)

# %% [markdown]
# ### 4.1.  <font color="royalblue">Bar Plot</font>

# %%
month = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"] # x축에 나타낼 index
data1 = [2, 4, 7, 23, 25, 57, 235, 129, 42, 13, 23, 3] # 나타내고 싶은 데이터1
data2 = [3, 5, 9, 26, 28, 70, 175, 182, 87, 18, 6, 3] # 나타내고 싶은 데이터 2
bar = pyecharts.Bar("Bar chart", "year graph") # 그래프 제목 및 소제목을 포함하여 bar 객체 생성
bar.add("data1", month, data1, mark_line=["average"], mark_point=["max", "min"]) # 나타내고 싶은 데이터1 bar에 추가
bar.add("data2", month, data2, mark_line=["average"], mark_point=["max", "min"]) # 나타내고 싶은 데이터2 bar에 추가

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6dd9a1371a724ddd9065a7e5085bf4fa" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6dd9a1371a724ddd9065a7e5085bf4fa = echarts.init(document.getElementById('6dd9a1371a724ddd9065a7e5085bf4fa'), 'light', {renderer: 'canvas'});
#
# var option_6dd9a1371a724ddd9065a7e5085bf4fa = {
#     "title": [
#         {
#             "text": "Bar chart",
#             "subtext": "year graph",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3456501,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "data1",
#             "data": [
#                 2,
#                 4,
#                 7,
#                 23,
#                 25,
#                 57,
#                 235,
#                 129,
#                 42,
#                 13,
#                 23,
#                 3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 3456501
#         },
#         {
#             "type": "bar",
#             "name": "data2",
#             "data": [
#                 3,
#                 5,
#                 9,
#                 26,
#                 28,
#                 70,
#                 175,
#                 182,
#                 87,
#                 18,
#                 6,
#                 3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 3456501
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "data1",
#                 "data2"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",

# %% [markdown]
# bar.add에서 mark_ine 이라는 인자는 그래프에서의 화살표를 나타내고, mark_point는 말풍선처럼 생긴 마커를 생성!

# %%
bar = pyecharts.Bar("가로 그래프") # 그래프 제목 포함한 bar 생성
bar.add("data1", month, data1) # A라는 이름으로 나타내고 싶은 데이터1 추가
bar.add("data2", month, data2, is_convert=True) # B라는 이름으로 나타내고 싶은 데이터2 추가
# is_convert=True 를 통해 막대가 수평 방향으로 바뀜
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="161ce6c7629743aea0731275878c9adf" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_161ce6c7629743aea0731275878c9adf = echarts.init(document.getElementById('161ce6c7629743aea0731275878c9adf'), 'light', {renderer: 'canvas'});
#
# var option_161ce6c7629743aea0731275878c9adf = {
#     "title": [
#         {
#             "text": "\uac00\ub85c \uadf8\ub798\ud504",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 484408,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "data1",
#             "data": [
#                 2,
#                 4,
#                 7,
#                 23,
#                 25,
#                 57,
#                 235,
#                 129,
#                 42,
#                 13,
#                 23,
#                 3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 484408
#         },
#         {
#             "type": "bar",
#             "name": "data2",
#             "data": [
#                 3,
#                 5,
#                 9,
#                 26,
#                 28,
#                 70,
#                 175,
#                 182,
#                 87,
#                 18,
#                 6,
#                 3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 484408
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "data1",
#                 "data2"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ]
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_161ce6c7629743aea0731275878c9adf.setOption(option_161ce6c7629743aea0731275878c9adf);
#
#     });
# </script>

# %% [markdown]
# ### 4.2.  <font color="royalblue">Line Plot</font>

# %%
from pyecharts import Bar, Line, Overlap

idx = ['A','B','C','D','E','F']
data1 = [10, 20, 30, 40, 50, 60]
data2 = [30, 40, 56, 78, 68, 34]

bar = Bar("Bar plot") # 그래프 이름 포함한 bar 객체 생성
bar.add("bar", idx, data1) # 막대를 추가
line = Line() # line 객체 생성
line.add("line", idx, data2) # 선을 추가

overlap = Overlap() # 겹쳐 그릴 수 있도록 overlap 객체 생성
overlap.add(bar) # 객체에 막대 추가
overlap.add(line) # 객체에 선 추가

overlap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="bd623fcb6d1043b3bd5c34a3f50f3663" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_bd623fcb6d1043b3bd5c34a3f50f3663 = echarts.init(document.getElementById('bd623fcb6d1043b3bd5c34a3f50f3663'), 'light', {renderer: 'canvas'});
#
# var option_bd623fcb6d1043b3bd5c34a3f50f3663 = {
#     "title": [
#         {
#             "text": "Bar plot",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 508701,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "bar",
#             "data": [
#                 10,
#                 20,
#                 30,
#                 40,
#                 50,
#                 60
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 508701
#         },
#         {
#             "type": "line",
#             "name": "line",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "A",
#                     30
#                 ],
#                 [
#                     "B",
#                     40
#                 ],
#                 [
#                     "C",
#                     56
#                 ],
#                 [
#                     "D",
#                     78
#                 ],
#                 [
#                     "E",
#                     68
#                 ],
#                 [
#                     "F",
#                     34
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 508701,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "bar",
#                 "line"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "A",
#                 "B",
#                 "C",
#                 "D",
#                 "E",
#                 "F"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_bd623fcb6d1043b3bd5c34a3f50f3663.setOption(option_bd623fcb6d1043b3bd5c34a3f50f3663);
#
#     });
# </script>

# %% [markdown]
# ### 4.3.  <font color="royalblue">Pie Plot</font>

# %%
from pyecharts import Pie

idx = ['A','B','C','D','E','F']
data1 = [10, 20, 30, 40, 50, 60]
data2 = [30, 40, 56, 78, 68, 34]

pie = Pie("pie chart", title_pos="center", width=600) # title_pos는 제목의 위치를 의미, 파이 객체 생성
pie.add("data1", idx, data1, center=[25, 50], is_random=True, radius=[20, 50]) #center는 중심의 위치, radius는 안원과 바깥원의 직경
pie.add("data2", idx, data2, center=[75, 50], is_randome=True, radius=[20, 50], is_legend_show=False,
       is_label_show=True)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b744627a45944da8a41f5bfb19eeeddd" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b744627a45944da8a41f5bfb19eeeddd = echarts.init(document.getElementById('b744627a45944da8a41f5bfb19eeeddd'), 'light', {renderer: 'canvas'});
#
# var option_b744627a45944da8a41f5bfb19eeeddd = {
#     "title": [
#         {
#             "text": "pie chart",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5389858,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "data1",
#             "data": [
#                 {
#                     "name": "A",
#                     "value": 10
#                 },
#                 {
#                     "name": "B",
#                     "value": 20
#                 },
#                 {
#                     "name": "C",
#                     "value": 30
#                 },
#                 {
#                     "name": "D",
#                     "value": 40
#                 },
#                 {
#                     "name": "E",
#                     "value": 50
#                 },
#                 {
#                     "name": "F",
#                     "value": 60
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "50%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 5389858
#         },
#         {
#             "type": "pie",
#             "name": "data2",
#             "data": [
#                 {
#                     "name": "A",
#                     "value": 30
#                 },
#                 {
#                     "name": "B",
#                     "value": 40
#                 },
#                 {
#                     "name": "C",
#                     "value": 56
#                 },
#                 {
#                     "name": "D",
#                     "value": 78
#                 },
#                 {
#                     "name": "E",
#                     "value": 68
#                 },
#                 {
#                     "name": "F",
#                     "value": 34
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "50%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 5389858
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B",
#                 "C",
#                 "D",
#                 "E",
#                 "F"
#             ],
#             "selectedMode": "multiple",
#             "show": false,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#6d8346",
#         "#6e7074",
#         "#1d953f",
#         "#ca8622",
#         "#c23531",
#         "#c4ccd3",
#         "#6950a1",
#         "#905a3d",
#         "#2a5caa",
#         "#d48265",
#         "#918597",
#         "#fab27b",
#         "#2f4554",
#         "#f47920",
#         "#726930",
#         "#444693",
#         "#b2d235",
#         "#546570",
#         "#f6f5ec",
#         "#bda29a",
#         "#f05b72",
#         "#ac6767",
#         "#749f83",
#         "#ef5b9c",
#         "#61a0a8"
#     ]
# };
# myChart_b744627a45944da8a41f5bfb19eeeddd.setOption(option_b744627a45944da8a41f5bfb19eeeddd);
#
#     });
# </script>

# %% [markdown]
# ### 4.4.  <font color="royalblue">Box Plot</font>

# %%
from pyecharts import Boxplot

boxplot = Boxplot("Box plot") # 박스플랏 객체 생성
x = ['data1', 'data2', 'data3', 'data4', 'data5'] # x축 데이터
y = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 900, 880,
    1000, 980, 930, 650, 760, 810, 1000, 100, 960, 960],
    [960, 940, 960, 940, 880, 830, 850, 880, 900, 840,
    830, 790, 800, 880, 880, 830, 800, 790, 760, 800],
    [880, 880, 880, 860, 720, 720, 620, 850, 970, 950,
    880, 910, 840, 870, 840, 840, 850, 840, 840, 840],
    [890, 810, 810, 810, 800, 770, 760, 740, 750, 760,
    910, 920, 890, 460, 880, 720, 840, 850, 850, 780],
    [890, 840, 780, 860, 760, 810, 790, 810, 820, 850,
    870, 870, 810, 770, 810, 940, 950, 800, 810, 870]
] # y축 데이터
_y = boxplot.prepare_data(y) # y축 데이터를 박스플랏에 맡게 변환       
boxplot.add("boxplot", x, _y)
boxplot
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0889555f6d3f49eeb5cd60c9221308a0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0889555f6d3f49eeb5cd60c9221308a0 = echarts.init(document.getElementById('0889555f6d3f49eeb5cd60c9221308a0'), 'light', {renderer: 'canvas'});
#
# var option_0889555f6d3f49eeb5cd60c9221308a0 = {
#     "title": [
#         {
#             "text": "Box plot",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4671661,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "boxplot",
#             "data": [
#                 [
#                     100,
#                     820.0,
#                     915.0,
#                     975.0,
#                     1070
#                 ],
#                 [
#                     760,
#                     800.0,
#                     845.0,
#                     895.0,
#                     960
#                 ],
#                 [
#                     620,
#                     840.0,
#                     850.0,
#                     880.0,
#                     970
#                 ],
#                 [
#                     460,
#                     760.0,
#                     810.0,
#                     872.5,
#                     920
#                 ],
#                 [
#                     760,
#                     802.5,
#                     815.0,
#                     870.0,
#                     950
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4671661
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "boxplot"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "data1",
#                 "data2",
#                 "data3",
#                 "data4",
#                 "data5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_0889555f6d3f49eeb5cd60c9221308a0.setOption(option_0889555f6d3f49eeb5cd60c9221308a0);
#
#     });
# </script>

# %% [markdown]
# ### 4.5.  <font color="royalblue">Funnel Plot</font>

# %%
from pyecharts import Funnel

idx = ["A", "B", "C", "D", "E", "F"]
data = [10, 20, 30, 40, 50, 60]
funnel = Funnel("퍼널 그래프")
funnel.add(
    "퍼널",
    idx,
    data,
    is_label_show=True,
    label_pos="inside", # 라벨 위치
    label_text_color="blue", # 라벨 글씨 색깔
)
funnel.width=700
funnel.height=500
funnel
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="cc13bf0fb5b64df58a1a2d9defffbb0c" style="width:700px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_cc13bf0fb5b64df58a1a2d9defffbb0c = echarts.init(document.getElementById('cc13bf0fb5b64df58a1a2d9defffbb0c'), 'light', {renderer: 'canvas'});
#
# var option_cc13bf0fb5b64df58a1a2d9defffbb0c = {
#     "title": [
#         {
#             "text": "\ud37c\ub110 \uadf8\ub798\ud504",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6662342,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\ud37c\ub110",
#             "data": [
#                 {
#                     "name": "A",
#                     "value": 10
#                 },
#                 {
#                     "name": "B",
#                     "value": 20
#                 },
#                 {
#                     "name": "C",
#                     "value": 30
#                 },
#                 {
#                     "name": "D",
#                     "value": 40
#                 },
#                 {
#                     "name": "E",
#                     "value": 50
#                 },
#                 {
#                     "name": "F",
#                     "value": 60
#                 }
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "blue",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "B",
#                 "D",
#                 "A",
#                 "E",
#                 "F",
#                 "C"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_cc13bf0fb5b64df58a1a2d9defffbb0c.setOption(option_cc13bf0fb5b64df58a1a2d9defffbb0c);
#
#     });
# </script>

# %% [markdown]
# ### 4.6.  <font color="royalblue">Gauge Plot</font>

# %%
from pyecharts import Gauge

gauge = Gauge("Gauge Graph") # gauge 객체 생성
gauge.add("진척률", "파이팅", 92.26)
gauge
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c53775f5e866446aa4f008bcae0a4629" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c53775f5e866446aa4f008bcae0a4629 = echarts.init(document.getElementById('c53775f5e866446aa4f008bcae0a4629'), 'light', {renderer: 'canvas'});
#
# var option_c53775f5e866446aa4f008bcae0a4629 = {
#     "title": [
#         {
#             "text": "Gauge Graph",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 428728,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{a} <br/>{b} : {c}%",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "gauge",
#             "detail": {
#                 "formatter": "{value}%"
#             },
#             "name": "\uc9c4\ucc99\ub960",
#             "min": 0,
#             "max": 100,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "value": 92.26,
#                     "name": "\ud30c\uc774\ud305"
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uc9c4\ucc99\ub960"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_c53775f5e866446aa4f008bcae0a4629.setOption(option_c53775f5e866446aa4f008bcae0a4629);
#
#     });
# </script>
